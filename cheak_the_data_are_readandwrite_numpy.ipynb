# %%
with open('same.json','r') as f:
    read = f.read()
    print(f"this is a json file of acctive user on instagram\n{read}")
# Out:
# this is a json file of acctive user on instagram
# {
#   "username": "you_now_me",
#   "full_name": "You Now Me",
#   "user_id": "9876543210",
#   "account_type": "public",
#   "bio": "Living in the moment âœ¨ | Digital Creator | Tech & Lifestyle",
#   "profile_picture_url": "https://example.com/profile.jpg",
#   "followers_count": 12540,
#   "following_count": 540,
#   "posts_count": 128,
#   "is_verified": false,
#   "is_private": false,
#   "is_active": true,
#   "account_created": "2022-06-15T10:30:00Z",
#   "last_active": "2026-03-02T09:15:00Z",
#   "engagement_rate": 4.8,
#   "contact_info": {
#     "email": "younowme@example.com",
#     "phone": null,
#     "website": "https://younowme.com"
#   },
#   "recent_posts": [
#     {
#       "post_id": "post_001",
#       "caption": "New beginnings ðŸš€",
#       "likes": 1540,
#       "comments": 120,
#       "posted_at": "2026-03-01T14:00:00Z",
#       "is_reel": false
#     },
#     {
#       "post_id": "post_002",
# ...

# %%
import numpy as np

# %%
arr = np.array([[read]])

# %%
print(arr)
# Out:
# [['{\n  "username": "you_now_me",\n  "full_name": "You Now Me",\n  "user_id": "9876543210",\n  "account_type": "public",\n  "bio": "Living in the moment âœ¨ | Digital Creator | Tech & Lifestyle",\n  "profile_picture_url": "https://example.com/profile.jpg",\n  "followers_count": 12540,\n  "following_count": 540,\n  "posts_count": 128,\n  "is_verified": false,\n  "is_private": false,\n  "is_active": true,\n  "account_created": "2022-06-15T10:30:00Z",\n  "last_active": "2026-03-02T09:15:00Z",\n  "engagement_rate": 4.8,\n  "contact_info": {\n    "email": "younowme@example.com",\n    "phone": null,\n    "website": "https://younowme.com"\n  },\n  "recent_posts": [\n    {\n      "post_id": "post_001",\n      "caption": "New beginnings ðŸš€",\n      "likes": 1540,\n      "comments": 120,\n      "posted_at": "2026-03-01T14:00:00Z",\n      "is_reel": false\n    },\n    {\n      "post_id": "post_002",\n      "caption": "Late night coding ðŸ’»ðŸ”¥",\n      "likes": 2100,\n      "comments": 245,\
# ...

# %%
arr.flatten()
# Out:
# array(['{\n  "username": "you_now_me",\n  "full_name": "You Now Me",\n  "user_id": "9876543210",\n  "account_type": "public",\n  "bio": "Living in the moment âœ¨ | Digital Creator | Tech & Lifestyle",\n  "profile_picture_url": "https://example.com/profile.jpg",\n  "followers_count": 12540,\n  "following_count": 540,\n  "posts_count": 128,\n  "is_verified": false,\n  "is_private": false,\n  "is_active": true,\n  "account_created": "2022-06-15T10:30:00Z",\n  "last_active": "2026-03-02T09:15:00Z",\n  "engagement_rate": 4.8,\n  "contact_info": {\n    "email": "younowme@example.com",\n    "phone": null,\n    "website": "https://younowme.com"\n  },\n  "recent_posts": [\n    {\n      "post_id": "post_001",\n      "caption": "New beginnings ðŸš€",\n      "likes": 1540,\n      "comments": 120,\n      "posted_at": "2026-03-01T14:00:00Z",\n      "is_reel": false\n    },\n    {\n      "post_id": "post_002",\n      "caption": "Late night coding ðŸ’»ðŸ”¥",\n      "likes": 2100,\n      "comments": 
# ...

# %%
arr.dtype
# Out:
# dtype('<U1129')

# %%
arr.size
# Out:
# 1

# %%
print(arr.dtype)
# Out:
# <U1129

# %% [raw]
# arr.split("\n")
