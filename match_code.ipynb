# %%
code = int(input("enter the match code number: "))
match code:
    case 200:
        print("response ok")
    case 400:
        print("server not found")
    case 404:
        print("server error")
    case _:
        print("match code not match")
print("end of this code")
