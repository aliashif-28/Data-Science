# %% [markdown]
# I am using a website link of my friend consent to approval collect the data

# %%
import requests

# %%
vikash_web = "https://predicthub-lac.vercel.app/prediction"
response = requests.get(vikash_web)

print(response.text)
# Out:
# <!doctype html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <link rel="icon" type="image/png" href="/predicthub-logo2.png" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>PredictHub</title>
#     <script type="module" crossorigin src="/assets/index-CLb2f-iv.js"></script>
#     <link rel="stylesheet" crossorigin href="/assets/index-BMoIlztg.css">
#   </head>
#   <body>
#     <div id="root"></div>
#   </body>
# </html>

# %%
vikash_web = "https://vikash-portfolio-gh6s.onrender.com/skill"
res = requests.get(vikash_web)

print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
#     <title>Skills | Portfolio</title>
#
#     <link rel="stylesheet"
#           href="/static/css/style.css">
# </head>
#
# <body>
#
#     <!-- ================= HEADER ================= -->
#     <header class="site-header">
#
#         <div class="container navbar">
#
#             <!-- Logo -->
#             <a href="/" class="logo">
#                 PORTFOLIO
#             </a>
#
#             <!-- Mobile Menu Button -->
#             <button class="menu-toggle"
#                     id="menuToggle"
#                     aria-label="Toggle navigation">
#                 ☰
#             </button>
#
#             <!-- Navigation -->
#             <nav class="nav-menu" id="navMenu">
#
#                 <a href="/"
#                    class="">
#                     Home
#                 </a>
#
# ...

# %%
code = res.text
with open ("code.html","a",encoding="utf-8") as f:
    f.write(code)
    print(code)
    f.close()
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
#     <title>Skills | Portfolio</title>
#
#     <link rel="stylesheet"
#           href="/static/css/style.css">
# </head>
#
# <body>
#
#     <!-- ================= HEADER ================= -->
#     <header class="site-header">
#
#         <div class="container navbar">
#
#             <!-- Logo -->
#             <a href="/" class="logo">
#                 PORTFOLIO
#             </a>
#
#             <!-- Mobile Menu Button -->
#             <button class="menu-toggle"
#                     id="menuToggle"
#                     aria-label="Toggle navigation">
#                 ☰
#             </button>
#
#             <!-- Navigation -->
#             <nav class="nav-menu" id="navMenu">
#
#                 <a href="/"
#                    class="">
#                     Home
#                 </a>
#
# ...

# %%
with open ("vikash.txt","w",encoding = "UTF-8") as f:
    f.write(code)
    f.close()

# %%
with open ("vikash1.txt","a",encoding = "UTF-8") as f:
    f.write(code)
    f.close()
